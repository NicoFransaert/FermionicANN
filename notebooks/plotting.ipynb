# %%
import numpy as np
from core import Psi4Model, XYZLogger #, load_xyz
import json
from scipy.signal import savgol_filter
import string

#https://github.com/molmod/molmod
from molmod.units import angstrom, debye, kjmol, kcalmol
from molmod.io.xyz import XYZReader

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os, sys

# %%
bondlength = np.load('../data/dissociation/STO-3G/bondlength_H2.npy')
HF_energy = np.load('../data/dissociation/STO-3G/scf_energy_H2.npy')
FCI_energy = np.load('../data/dissociation/STO-3G/FCI_energy_H2.npy')
CCSD_energy = np.load('../data/dissociation/STO-3G/CCSD_energy_H2.npy')
CCSDT_energy = np.load('../data/dissociation/STO-3G/CCSD(T)_energy_H2.npy')

fig, ax = plt.subplots(1, 1, figsize=(5,4), squeeze=False, dpi=150)

ax = ax[0][0]
ax.plot(bondlength, HF_energy, linestyle='--', c='blue', label='HF')
ax.plot(bondlength, FCI_energy, linestyle='--', c='red', label='FCI')
ax.plot(bondlength, CCSD_energy, linestyle='--', linewidth=0.7, c='black', label='CCSD')
ax.plot(bondlength, CCSDT_energy, linestyle='dotted', linewidth=0.7, c='black', label='CCSD(T)')
ax.set_xlabel('Nuclear separation ($\AA$)')
ax.set_ylabel('Energy ($Ha$)')
ax.legend(loc='upper right', fontsize='large', ncol=2)

ins = ax.inset_axes([0.3,0.49,0.28,0.25])

ins.plot(bondlength, HF_energy, linestyle='--', c='blue')
ins.plot(bondlength, FCI_energy, linestyle='--', c='red')
ins.plot(bondlength, CCSD_energy, linestyle='--', linewidth=0.7, c='black')
ins.plot(bondlength, CCSDT_energy, linestyle='dotted', linewidth=0.7, c='black')
ins.set_xticks([0.65,0.734,0.8])
ins.set_xlim(0.65,0.8)
ins.set_ylim(-1.14, -1.13)
#plt.title('Probability')
# Out:
# (-1.14, -1.13)

# %%
bondlength = np.load('../data/dissociation/6-31g/bondlength_H2.npy')
HF_energy = np.load('../data/dissociation/6-31g/scf_energy_H2.npy')
FCI_energy = np.load('../data/dissociation/6-31g/FCI_energy_H2.npy')
CCSD_energy = np.load('../data/dissociation/6-31g/CCSD_energy_H2.npy')
CCSDT_energy = np.load('../data/dissociation/6-31g/CCSD(T)_energy_H2.npy')

fig, ax = plt.subplots(1, 1, figsize=(5,4), squeeze=False, dpi=150)

ax = ax[0][0]
ax.plot(bondlength, HF_energy, linestyle='--', c='blue', label='HF')
ax.plot(bondlength, FCI_energy, linestyle='--', c='red', label='FCI')
ax.plot(bondlength, CCSD_energy, linestyle='--', linewidth=0.7, c='black', label='CCSD')
ax.plot(bondlength, CCSDT_energy, linestyle='dotted', linewidth=0.7, c='black', label='CCSD(T)')
ax.set_xlabel('Nuclear separation ($\AA$)')
ax.set_ylabel('Energy ($Ha$)')
ax.legend(loc='upper right', fontsize='large', ncol=2)

ins = ax.inset_axes([0.3,0.49,0.28,0.25])

ins.plot(bondlength, HF_energy, linestyle='--', c='blue')
ins.plot(bondlength, FCI_energy, linestyle='--', c='red')
ins.plot(bondlength, CCSD_energy, linestyle='--', linewidth=0.7, c='black')
ins.plot(bondlength, CCSDT_energy, linestyle='dotted', linewidth=0.7, c='black')
ins.set_xticks([0.7,0.746,0.8])
ins.set_xlim(0.7,0.8)
ins.set_ylim(-1.155, -1.145)
#plt.title('Probability')
# Out:
# (-1.155, -1.145)

# %%
bondlength = np.load('../data/dissociation/STO-3G/bondlength_LiH.npy')
HF_energy = np.load('../data/dissociation/STO-3G/scf_energy_LiH.npy')
FCI_energy = np.load('../data/dissociation/STO-3G/FCI_energy_LiH.npy')
CCSD_energy = np.load('../data/dissociation/STO-3G/CCSD_energy_LiH.npy')
CCSDT_energy = np.load('../data/dissociation/STO-3G/CCSD(T)_energy_LiH.npy')

fig, ax = plt.subplots(1, 1, figsize=(5,4), squeeze=False, dpi=150)

ax = ax[0][0]
ax.plot(bondlength, HF_energy, linestyle='--', c='blue', label='HF')
ax.plot(bondlength, FCI_energy, linestyle='--', c='red', label='FCI')
ax.plot(bondlength, CCSD_energy, linestyle='--', linewidth=0.7, c='black', label='CCSD')
ax.plot(bondlength, CCSDT_energy, linestyle='dotted', linewidth=0.7, c='black', label='CCSD(T)')
ax.set_xlabel('Nuclear separation ($\AA$)')
ax.set_ylabel('Energy ($Ha$)')
ax.legend(loc='upper right', fontsize='large', ncol=2)

ins = ax.inset_axes([0.29,0.49,0.26,0.25])

ins.plot(bondlength, HF_energy, linestyle='--', c='blue')
ins.plot(bondlength, FCI_energy, linestyle='--', c='red')
ins.plot(bondlength, CCSD_energy, linestyle='--', linewidth=0.7, c='black')
ins.plot(bondlength, CCSDT_energy, linestyle='dotted', linewidth=0.7, c='black')
ins.set_xticks([1.45,1.548,1.65])
ins.set_xlim(1.45,1.65)
ins.set_yticks([-7.885, -7.88])
ins.set_ylim(-7.885, -7.88)
#plt.title('Probability')
# Out:
# (-7.885, -7.88)

# %%
bondlength = np.load('../data/dissociation/6-31g/bondlength_LiH.npy')
HF_energy = np.load('../data/dissociation/6-31g/scf_energy_LiH.npy')
FCI_energy = np.load('../data/dissociation/6-31g/FCI_energy_LiH.npy')
CCSD_energy = np.load('../data/dissociation/6-31g/CCSD_energy_LiH.npy')
CCSDT_energy = np.load('../data/dissociation/6-31g/CCSD(T)_energy_LiH.npy')

fig, ax = plt.subplots(1, 1, figsize=(5,4), squeeze=False, dpi=150)

ax = ax[0][0]
ax.plot(bondlength, HF_energy, linestyle='--', c='blue', label='HF')
ax.plot(bondlength, FCI_energy, linestyle='--', c='red', label='FCI')
ax.plot(bondlength, CCSD_energy, linestyle='--', linewidth=0.7, c='black', label='CCSD')
ax.plot(bondlength, CCSDT_energy, linestyle='dotted', linewidth=0.7, c='black', label='CCSD(T)')
ax.set_xlabel('Nuclear separation ($\AA$)')
ax.set_ylabel('Energy ($Ha$)')
ax.legend(loc='upper right', fontsize='large', ncol=2)

ins = ax.inset_axes([0.34,0.49,0.26,0.25])

ins.plot(bondlength, HF_energy, linestyle='--', c='blue')
ins.plot(bondlength, FCI_energy, linestyle='--', c='red')
ins.plot(bondlength, CCSD_energy, linestyle='--', linewidth=0.7, c='black')
ins.plot(bondlength, CCSDT_energy, linestyle='dotted', linewidth=0.7, c='black')
ins.set_xticks([1.6,1.672,1.75])
ins.set_xlim(1.6,1.75)
ins.set_yticks([-8.0, -7.995])
ins.set_ylim(-8.0, -7.995)
#plt.title('Probability')
# Out:
# (-8.0, -7.995)

# %%
bondlength = np.load('../data/dissociation/STO-3G/bondlength_C2.npy')
HF_energy = np.load('../data/dissociation/STO-3G/scf_energy_C2.npy')
FCI_energy = np.load('../data/dissociation/STO-3G/FCI_energy_C2.npy')
CCSD_energy = np.load('../data/dissociation/STO-3G/CCSD_energy_C2.npy')
CCSDT_energy = np.load('../data/dissociation/STO-3G/CCSD(T)_energy_C2.npy')

fig, ax = plt.subplots(1, 1, figsize=(5,4), squeeze=False, dpi=150)

ax = ax[0][0]
ax.plot(bondlength, HF_energy, linestyle='--', c='blue', label='HF')
ax.plot(bondlength, FCI_energy, linestyle='--', c='red', label='FCI')
ax.plot(bondlength, CCSD_energy, linestyle='--', linewidth=0.7, c='black', label='CCSD')
ax.plot(bondlength, CCSDT_energy, linestyle='dotted', linewidth=0.7, c='black', label='CCSD(T)')
ax.set_xlabel('Nuclear separation ($\AA$)')
ax.set_ylabel('Energy ($Ha$)')
ax.legend(loc='upper right', fontsize='large', ncol=2)

ins = ax.inset_axes([0.45,0.49,0.28,0.25])

ins.plot(bondlength, HF_energy, linestyle='--', c='blue')
ins.plot(bondlength, FCI_energy, linestyle='--', c='red')
ins.plot(bondlength, CCSD_energy, linestyle='--', linewidth=0.7, c='black')
ins.plot(bondlength, CCSDT_energy, linestyle='dotted', linewidth=0.7, c='black')
ins.set_xticks([1.15,1.26,1.35])
ins.set_xlim(1.15,1.35)
ins.set_ylim(-74.7, -74.65)
#plt.title('Probability')
# Out:
# (-74.7, -74.65)

# %%
bondlength = np.load('../data/dissociation/STO-3G/bondlength_N2.npy')
HF_energy = np.load('../data/dissociation/STO-3G/scf_energy_N2.npy')
FCI_energy = np.load('../data/dissociation/STO-3G/FCI_energy_N2.npy')
CCSD_energy = np.load('../data/dissociation/STO-3G/CCSD_energy_N2.npy')
CCSDT_energy = np.load('../data/dissociation/STO-3G/CCSD(T)_energy_N2.npy')

fig, ax = plt.subplots(1, 1, figsize=(5,4), squeeze=False, dpi=150)

ax = ax[0][0]
ax.plot(bondlength, HF_energy, linestyle='--', c='blue', label='HF')
ax.plot(bondlength, FCI_energy, linestyle='--', c='red', label='FCI')
ax.plot(bondlength, CCSD_energy, linestyle='--', linewidth=0.7, c='black', label='CCSD')
ax.plot(bondlength, CCSDT_energy, linestyle='dotted', linewidth=0.7, c='black', label='CCSD(T)')
ax.set_xlabel('Nuclear separation ($\AA$)')
ax.set_ylabel('Energy ($Ha$)')
ax.legend(loc='upper right', fontsize='large', ncol=2)

ins = ax.inset_axes([0.32,0.49,0.24,0.25])

ins.plot(bondlength, HF_energy, linestyle='--', c='blue')
ins.plot(bondlength, FCI_energy, linestyle='--', c='red')
ins.plot(bondlength, CCSD_energy, linestyle='--', linewidth=0.7, c='black')
ins.plot(bondlength, CCSDT_energy, linestyle='dotted', linewidth=0.7, c='black')
ins.set_xticks([1.1,1.19,1.3])
ins.set_xlim(1.1,1.3)
ins.ticklabel_format(useOffset=False)
ins.set_yticks([-107.69, -107.64])
ins.set_ylim(-107.69, -107.64)
#plt.title('Probability')
# Out:
# (-107.69, -107.64)

# %% [markdown]
# ## RBM

# %%
meta_file_H2 = '../data/RBM_runs/dissociation_H2/rbm_sto3g_H2_0-7348_eq1_a1_sgd_lr1_ns10000_trick.META'
hist_file_H2 = '../data/RBM_runs/dissociation_H2/rbm_sto3g_H2_0-7348_eq1_a1_sgd_lr1_ns10000_trick.log'
with open(meta_file_H2) as jf:
    meta = json.load(jf)
with open(hist_file_H2) as jf:
    hist = json.load(jf)
it = [i['Iteration'] for i in hist['Output']]
en = [i['Energy']['Mean'] + meta['SystemData']['nuc_rep_energy'] for i in hist['Output']]
exact = meta['SystemData']['tot_energy']

fig, ax = plt.subplots(1, 1, figsize=(5,4), squeeze=False, dpi=150)
ax = ax[0][0]
#plot energy history
# plt.plot(it, en)
# plt.title(r'$H_2$ @ equilibrium')
# plt.xlabel('Iteration')
# plt.ylabel('Energy')

#plot relative energy error
ax.plot(it, np.abs((np.array(en)-exact)/exact), color='b', label='H$_2$ RBM')
# plt.title(r'$H_2$ equilibrium')
ax.hlines(kcalmol, xmin=0, xmax=it[-1], linestyles='--', color='k', label='chemical accuracy')
ax.set_xlabel('iterations')
ax.set_ylabel(r'$\Delta E_0$ ($Ha$)')
ax.set_yscale('log')
ax.legend()

# %%
# Annotation, e.g. (a), (b)...
for n, ax in enumerate(subplots.flat):
    ax.text(-0.1, 1.1, '('+string.ascii_lowercase[n]+')', transform=ax.transAxes, size=size)

# %%
hist_file = '../data/RNN_runs/sweep_H2/rnn_sto3g_H2_0-7348_eq1_nU50_nL1_lr005_lrsC_ns100000.log'

with open(hist_file) as jf:
    hist = json.load(jf)

var_en1 = np.array([i['EnergyVariance']['Mean'] for i in hist['Output']])/(hist['Output'][-1]['Energy']['Mean'])**2


hist_file = '../data/RBM_runs/H2_for_plot/rbm_sto3g_H2_0-7348_eq1_a1_sgd_lr01_ns10000_trick.log'

with open(hist_file) as jf:
    hist = json.load(jf)

var_en2 = np.array([i['Energy']['Variance'] for i in hist['Output']])[:5000]/(hist['Output'][-1]['Energy']['Mean'])**2

fig, ax = plt.subplots(1,1, figsize=(8,3.5), squeeze=False, dpi=120)

while 0 in var_en1:
    zero_idx = np.where(var_en1 == 0.)
    var_en1[zero_idx] = var_en1[np.array(zero_idx, dtype=int)-1]
while 0 in var_en2:
    zero_idx = np.where(var_en2 == 0.)
    var_en2[zero_idx] = var_en2[np.array(zero_idx, dtype=int)-1]

ax1 = ax[0,0]
ax1.plot(var_en2, c='g')
ax1.plot(var_en1, c='b')
ax1.set_yscale('log')
ax1.set_xlabel('Iterations')
ax1.set_ylabel('Relative Energy Variance')
ax1.set_ylim(5e-08,1e+04)
# Out:
# (5e-08, 10000.0)

# %%
meta_file = '../data/RBM_runs/H2_for_plot/rbm_sto3g_H2_0-7348_eq1_a1_sgd_lr01_ns10000_trick.META'
hist_file = '../data/RBM_runs/H2_for_plot/rbm_sto3g_H2_0-7348_eq1_a1_sgd_lr01_ns10000_trick.log'

with open(meta_file) as jf:
    meta = json.load(jf)
with open(hist_file) as jf:
    hist = json.load(jf)
it1 = [i['Iteration'] for i in hist['Output']][0:4000]
en1 = [i['Energy']['Mean'] + meta['SystemData']['nuc_rep_energy'] for i in hist['Output']][0:4000]
var_en1 = np.array([i['Energy']['Variance'] for i in hist['Output']])[:4000]/(hist['Output'][-1]['Energy']['Mean'])**2
exact = meta['SystemData']['tot_energy']

while 0 in var_en1:
    zero_idx = np.where(var_en1 == 0.)
    var_en1[zero_idx] = var_en1[np.array(zero_idx, dtype=int)-1]

meta_file = '../data/RNN_runs/sweep_H2/rnn_sto3g_H2_0-7348_eq1_nU50_nL1_lr005_lrsC_ns100000.META'
hist_file = '../data/RNN_runs/sweep_H2/rnn_sto3g_H2_0-7348_eq1_nU50_nL1_lr005_lrsC_ns100000.log'

with open(meta_file) as jf:
    meta = json.load(jf)
with open(hist_file) as jf:
    hist = json.load(jf)
it2 = [i['Iteration'] for i in hist['Output']][0:4000]
en2 = [i['Energy']['Mean'] + meta['SystemData']['nuc_rep_energy'] for i in hist['Output']][0:4000]
var_en2 = np.array([i['EnergyVariance']['Mean'] for i in hist['Output']])[0:4000]/(hist['Output'][-1]['Energy']['Mean'])**2

while 0 in var_en2:
    zero_idx = np.where(var_en2 == 0.)
    var_en2[zero_idx] = var_en2[np.array(zero_idx, dtype=int)-1]

gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(8,7), dpi=150)

for n, subplt in enumerate(ax.flat):
    subplt.text(-0.1, -0.1, '('+string.ascii_lowercase[n]+')', transform=subplt.transAxes, size=15)

ax2 = plt.subplot(gs[0, 0]) # row 0, col 0
ax1 = plt.subplot(gs[0, 1]) # row 0, col 0
ax3 = plt.subplot(gs[1, :])

ax2.text(-0.1, -0.1, '(a)', transform=ax2.transAxes, size=15)
ax1.text(-0.1, -0.1, '(b)', transform=ax1.transAxes, size=15)
ax3.text(-0.1, -0.1, '(c)', transform=ax3.transAxes, size=15)

#plot relative energy error
ax1.plot(it1, savgol_filter(np.abs((np.array(en1)-exact)/exact),51,3), color='b')
ax1.plot(it2, np.abs((np.array(en2)-exact)/exact), color='forestgreen')
# plt.title(r'$H_2$ equilibrium')
ax1.hlines(-kcalmol/exact, xmin=0, xmax=it1[-1], linestyles='--', color='r', label='chemical accuracy')
ax1.set_xlabel('Iterations')
ax1.set_ylabel(r'$\Delta E_0$ ($Ha$)')
ax1.set_yscale('log')
ax1.legend(loc='upper right')

ins = ax2.inset_axes([0.45,0.45,0.35,0.35])

ins.plot(np.array(it2), en2, color='forestgreen')
ins.hlines(-1.1170273947894147, xmin=0, xmax=it1[-1], linestyles='dotted', color='k', label='HF energy')
ins.set_xlim([3500, 4000])
# ins.set_xticks([1.1,1.19,1.3])
# ins.set_xlim(1.1,1.3)
ins.ticklabel_format(useOffset=False)
# ins.set_yticks([-1.119, -1.118, -1.1165])
ins.set_ylim(-1.119, -1.1165)

#plot energy history
ax2.plot(np.array(it1), savgol_filter(en1,51,3), color='b')
ax2.plot(np.array(it2), en2, color='forestgreen')
ax2.hlines(-1.1170273947894147, xmin=0, xmax=it1[-1], linestyles='dotted', color='k', label='HF energy')
# ax2.set_title('$H_2$ @ equilibrium')
ax2.set_xlabel('Iterations')
ax2.set_ylabel('Energy ($Ha$)')
ax2.set_ylim([-1.15,-1.0])
ax2.legend()

ax3.plot(var_en1, c='b', label='RBM')
ax3.plot(var_en2, c='g', label='RNN')
ax3.set_yscale('log')
ax3.set_xlabel('Iterations')
ax3.set_ylabel('Relative Variance of Hamiltonian')
ax3.set_ylim(5e-08,1e+04)
ax3.legend()

fig.tight_layout()
# plt.savefig('../data/plots/STO-3G_H2_history_with_var.png')

# %%
meta_file = '../data/RBM_runs/H2_for_plot/rbm_sto3g_H2_0-7348_eq1_a1_sgd_lr01_ns10000_trick.META'
hist_file = '../data/RBM_runs/H2_for_plot/rbm_sto3g_H2_0-7348_eq1_a1_sgd_lr01_ns10000_trick.log'

with open(meta_file) as jf:
    meta = json.load(jf)
with open(hist_file) as jf:
    hist = json.load(jf)
it1 = [i['Iteration'] for i in hist['Output']][0:4000]
en1 = [i['Energy']['Mean'] + meta['SystemData']['nuc_rep_energy'] for i in hist['Output']][0:4000]
exact = meta['SystemData']['tot_energy']

meta_file = '../data/RNN_runs/sweep_H2/rnn_sto3g_H2_0-7348_eq1_nU50_nL1_lr005_lrsC_ns100000.META'
hist_file = '../data/RNN_runs/sweep_H2/rnn_sto3g_H2_0-7348_eq1_nU50_nL1_lr005_lrsC_ns100000.log'

with open(meta_file) as jf:
    meta = json.load(jf)
with open(hist_file) as jf:
    hist = json.load(jf)
it2 = [i['Iteration'] for i in hist['Output']][0:4000]
en2 = [i['Energy']['Mean'] + meta['SystemData']['nuc_rep_energy'] for i in hist['Output']][0:4000]

fig, ax = plt.subplots(1, 2, figsize=(8,3.5), squeeze=False, dpi=300)

for n, subplt in enumerate(ax.flat):
    subplt.text(-0.1, -0.1, '('+string.ascii_lowercase[n]+')', transform=subplt.transAxes, size=15)

ax2 = ax[0][0]
ax1 = ax[0][1]

#plot relative energy error
ax1.plot(it1, savgol_filter(np.abs((np.array(en1)-exact)/exact),51,3), color='b', label='RBM')
ax1.plot(it2, np.abs((np.array(en2)-exact)/exact), color='forestgreen', label='RNN')
# plt.title(r'$H_2$ equilibrium')
ax1.hlines(-kcalmol/exact, xmin=0, xmax=it[-1], linestyles='--', color='r', label='chemical accuracy')
ax1.set_xlabel('Iterations')
ax1.set_ylabel(r'$\Delta E_0$ ($Ha$)')
ax1.set_yscale('log')
ax1.legend(loc='upper right')

ins = ax2.inset_axes([0.45,0.45,0.35,0.35])

ins.plot(np.array(it2), en2, color='forestgreen')
ins.hlines(-1.1170273947894147, xmin=0, xmax=it[-1], linestyles='dotted', color='k', label='HF energy')
ins.set_xlim([3500, 4000])
# ins.set_xticks([1.1,1.19,1.3])
# ins.set_xlim(1.1,1.3)
ins.ticklabel_format(useOffset=False)
# ins.set_yticks([-1.119, -1.118, -1.1165])
ins.set_ylim(-1.119, -1.1165)

#plot energy history
ax2.plot(np.array(it1), savgol_filter(en1,51,3), color='b')
ax2.plot(np.array(it2), en2, color='forestgreen')
ax2.hlines(-1.1170273947894147, xmin=0, xmax=it[-1], linestyles='dotted', color='k', label='HF energy')
# ax2.set_title('$H_2$ @ equilibrium')
ax2.set_xlabel('Iterations')
ax2.set_ylabel('Energy ($Ha$)')
ax2.set_ylim([-1.15,-1.0])
ax2.legend()

fig.tight_layout()
# plt.savefig('../data/plots/STO-3G_H2_history.png')

# %%
meta_file = '../data/RBM_runs/H2_for_plot/rbm_sto3g_H2_0-7348_eq1_a1_sgd_lr01_ns10000_trick.META'
hist_file = '../data/RBM_runs/H2_for_plot/rbm_sto3g_H2_0-7348_eq1_a1_sgd_lr01_ns10000_trick.log'

with open(meta_file) as jf:
    meta = json.load(jf)
with open(hist_file) as jf:
    hist = json.load(jf)
it1 = [i['Iteration'] for i in hist['Output']][0:4000]
en1 = [i['Energy']['Mean'] + meta['SystemData']['nuc_rep_energy'] for i in hist['Output']][0:4000]
exact = meta['SystemData']['tot_energy']

meta_file = '../data/RNN_runs/sweep_H2/rnn_sto3g_H2_0-7348_eq1_nU50_nL1_lr005_lrsC_ns100000.META'
hist_file = '../data/RNN_runs/sweep_H2/rnn_sto3g_H2_0-7348_eq1_nU50_nL1_lr005_lrsC_ns100000.log'

with open(meta_file) as jf:
    meta = json.load(jf)
with open(hist_file) as jf:
    hist = json.load(jf)
it2 = [i['Iteration'] for i in hist['Output']][0:4000]
en2 = [i['Energy']['Mean'] + meta['SystemData']['nuc_rep_energy'] for i in hist['Output']][0:4000]

fig, ax = plt.subplots(1, 2, figsize=(8,3.5), squeeze=False, dpi=300)

for n, subplt in enumerate(ax.flat):
    subplt.text(-0.1, -0.1, '('+string.ascii_lowercase[n]+')', transform=subplt.transAxes, size=15)

ax2 = ax[0][0]
ax1 = ax[0][1]

#plot relative energy error
ax1.plot(it1, savgol_filter(np.abs((np.array(en1)-exact)/exact),51,3), color='b', label='RBM')
# ax1.plot(it2, np.abs((np.array(en2)-exact)/exact), color='forestgreen', label='RNN')
# plt.title(r'$H_2$ equilibrium')
ax1.hlines(-kcalmol/exact, xmin=0, xmax=it[-1], linestyles='--', color='r', label='chemical accuracy')
ax1.set_xlabel('Iterations')
ax1.set_ylabel(r'$\Delta E_0$ ($Ha$)')
ax1.set_yscale('log')
ax1.legend(loc='upper right')

# ins = ax2.inset_axes([0.45,0.45,0.35,0.35])

# ins.plot(np.array(it2), en2, color='forestgreen')
# ins.hlines(-1.1170273947894147, xmin=0, xmax=it[-1], linestyles='dotted', color='k', label='HF energy')
# ins.set_xlim([3500, 4000])
# # ins.set_xticks([1.1,1.19,1.3])
# # ins.set_xlim(1.1,1.3)
# ins.ticklabel_format(useOffset=False)
# # ins.set_yticks([-1.119, -1.118, -1.1165])
# ins.set_ylim(-1.119, -1.1165)

#plot energy history
ax2.plot(np.array(it1), savgol_filter(en1,51,3), color='b')
# ax2.plot(np.array(it2), en2, color='forestgreen')
ax2.hlines(-1.1170273947894147, xmin=0, xmax=it[-1], linestyles='dotted', color='k', label='HF energy')
# ax2.set_title('$H_2$ @ equilibrium')
ax2.set_xlabel('Iterations')
ax2.set_ylabel('Energy ($Ha$)')
ax2.set_ylim([-1.15,-1.0])
ax2.legend()

fig.tight_layout()
# plt.savefig('../data/plots/STO-3G_H2_history_rbm.png')

# %%
np.argwhere(np.array(en2)<-1.13)
# Out:
# array([], shape=(0, 1), dtype=int64)

# %%
meta_file = '../data/RBM_runs/sweep2_LiH/rbm_sto3g_LiH_1-5474_eq1_a1_sgd_lr1_ns100000_trick.META'
hist_file = '../data/RBM_runs/sweep2_LiH/rbm_sto3g_LiH_1-5474_eq1_a1_sgd_lr1_ns100000_trick.log'

with open(meta_file) as jf:
    meta = json.load(jf)
with open(hist_file) as jf:
    hist = json.load(jf)
it = [i['Iteration'] for i in hist['Output']][0:4000]
en = [i['Energy']['Mean'] + meta['SystemData']['nuc_rep_energy'] for i in hist['Output']][0:4000]
exact = meta['SystemData']['tot_energy']

meta_file = '../data/RBM_runs/C2_final_test/rbm_sto3g_C2_1-2600_eq1_a1_sgd_lr1_ns10000_trick.META'
hist_file = '../data/RBM_runs/C2_final_test/rbm_sto3g_C2_1-2600_eq1_a1_sgd_lr1_ns10000_trick.log'

with open(meta_file) as jf:
    meta = json.load(jf)
with open(hist_file) as jf:
    hist = json.load(jf)
it1 = [i['Iteration'] for i in hist['Output']][0:4000]
en1 = [i['Energy']['Mean'] + meta['SystemData']['nuc_rep_energy'] for i in hist['Output']][0:4000]
exact1 = meta['SystemData']['tot_energy']

fig, ax = plt.subplots(1, 2, figsize=(8,3.5), squeeze=False, dpi=300)

for n, subplt in enumerate(ax.flat):
    subplt.text(-0.1, -0.1, '('+string.ascii_lowercase[n]+')', transform=subplt.transAxes, size=15)

ax1 = ax[0][0]
ax2 = ax[0][1]

#plot energy history
ax1.plot(np.array(it), savgol_filter(en,51,3), color='b', label='LiH - RBM')
ax1.hlines(-7.863190101746813, xmin=0, xmax=it[-1], linestyles='dotted', color='k', label='HF energy')
# ax1.set_title('$H_2$ @ equilibrium')
ax1.set_xlabel('Iterations')
ax1.set_ylabel('Energy ($Ha$)')
ax1.set_ylim([-7.9,-7.5])
ax1.legend()

ins = ax1.inset_axes([0.35,0.35,0.4,0.4])

ins.plot(np.array(it), savgol_filter(en,51,3), color='b')
ins.hlines(-7.863190101746813, xmin=0, xmax=it[-1], linestyles='dotted', color='k', label='HF energy')
ins.set_xlim([3500, 4000])
# ins.set_xticks([1.1,1.19,1.3])
# ins.set_xlim(1.1,1.3)
ins.ticklabel_format(useOffset=False)
# ins.set_yticks([-107.69, -107.64])
ins.set_ylim(-7.865, -7.862)


#plot energy history
ax2.plot(np.array(it1), savgol_filter(en1,51,3), color='b', label='C$_2$ - RBM')
ax2.hlines(-74.42111640394793, xmin=0, xmax=it1[-1], linestyles='dotted', color='k', label='HF energy')
# ax2.set_title('$H_2$ @ equilibrium')
ax2.set_xlabel('Iterations')
ax2.set_ylabel('Energy ($Ha$)')
ax2.set_ylim([-75,-70])
ax2.legend()

ins2 = ax2.inset_axes([0.35,0.35,0.4,0.4])

ins2.plot(np.array(it1), savgol_filter(en1,51,3), color='b')
ins2.hlines(-74.42111640394793, xmin=0, xmax=it1[-1], linestyles='dotted', color='k', label='HF energy')
ins2.set_xlim([1500, 2000])
# ins.set_xticks([1.1,1.19,1.3])
# ins.set_xlim(1.1,1.3)
ins2.ticklabel_format(useOffset=False)
# ins.set_yticks([-107.69, -107.64])
ins2.set_ylim(-74.75, -74.3)

fig.tight_layout()
# plt.savefig('../data/plots/STO-3G_LiH_C2_history.png')

# %%
bondlength = np.load('../data/dissociation/STO-3G/bondlength_H2.npy')
HF_energy = np.load('../data/dissociation/STO-3G/scf_energy_H2.npy')
FCI_energy = np.load('../data/dissociation/STO-3G/FCI_energy_H2.npy')
CCSD_energy = np.load('../data/dissociation/STO-3G/CCSD_energy_H2.npy')
CCSDT_energy = np.load('../data/dissociation/STO-3G/CCSD(T)_energy_H2.npy')

directory = '../data/RBM_runs/dissociation_H2/'
meta_files = []
for json_file in [f for f in os.listdir(directory) if f.endswith('.META')]:
    with open(directory + json_file) as jf:
        meta_files.append(json.load(jf))

rbm_bondlength = []
rbm_energies = []
rbm_sigma = []
for mf in meta_files:
    rbm_bondlength.append(mf['SystemData']['distance'])
    rbm_energies.append(mf['Total_energy']['Mean'])
    rbm_sigma.append(mf['Total_energy']['Sigma'])

fig, axs = plt.subplots(1, 1, figsize=(5,4), squeeze=False, dpi=150)

ax = axs[0][0]
ax.plot(bondlength, HF_energy, linestyle='--', c='blue', label='HF')
ax.plot(bondlength, FCI_energy, linestyle='--', c='red', label='FCI')
# ax.plot(bondlength, CCSD_energy, linestyle='--', linewidth=0.7, c='black', label='CCSD')
# ax.plot(bondlength, CCSDT_energy, linestyle='dotted', linewidth=0.7, c='black', label='CCSD(T)')
ax.errorbar(rbm_bondlength, rbm_energies, yerr=rbm_sigma, linestyle='', marker='x', c='green', capsize=3, label='RBM')
ax.set_xlabel('Nuclear separation ($\AA$)')
ax.set_ylabel('Energy ($Ha$)')
ax.legend(loc='upper right', fontsize='medium', ncol=2)

ins = ax.inset_axes([0.3,0.49,0.28,0.25])

ins.plot(bondlength, HF_energy, linestyle='--', c='blue')
ins.plot(bondlength, FCI_energy, linestyle='--', c='red')
# ins.plot(bondlength, CCSD_energy, linestyle='--', linewidth=0.7, c='black')
# ins.plot(bondlength, CCSDT_energy, linestyle='dotted', linewidth=0.7, c='black')
ins.errorbar(rbm_bondlength, rbm_energies, yerr=rbm_sigma, linestyle='', marker='x', c='green', capsize=3, label='RBM')
ins.set_xticks([0.65,0.734,0.8])
ins.set_xlim(0.65,0.8)
ins.set_ylim(-1.14, -1.13)
#plt.title('Probability')
ax.axis('tight')
fig.tight_layout()

# plt.savefig('../data/plots/STO-3G_H2_dissociation.png')

# %%
directory = '../data/RNN_runs/sweep_H2/'
meta_files = []
for json_file in [f for f in os.listdir(directory) if f.endswith('.META')]:
    with open(directory + json_file) as jf:
        meta_files.append(json.load(jf))

rbm_bondlength = []
rbm_energies = []
rbm_sigma = []
for mf in meta_files:
    rbm_bondlength.append(mf['SystemData']['distance'])
    rbm_energies.append(mf['Total_energy']['Mean'])
    rbm_sigma.append(mf['Training']['numsamples'])
rbm_energies = np.array(rbm_energies)

# %%
rbm_energies[18]
# Out:
# -1.1183663032829871

# %%
rbm_energies[[0,3,17,21,28,32,45,47,54,63,66,67]]
# Out:
# array([-1.11837226, -1.11832267, -1.11827117, -1.11837226, -1.11815852,
#        -1.11837226, -1.11836034, -1.11831862, -1.11837226, -1.11834854,
#        -1.11835426, -1.11835426])

# %%
rbm_sigma[18]
# Out:
# 100000

# %%
meta_files[[0,3,17,21,28,32,45,47,54,63,66,67]]

# %%
meta_files[18]
# Out:
# {'SystemData': {'molecule': 'H2',
#   'basis': 'sto3g',
#   'n_basisfuncs': 4,
#   'distance': 0.7348999999999997,
#   'atomstring': 'H 0.0 0.0 0.0; H 0.0 0.0 0.734900',
#   'eq': True,
#   'tot_energy': -1.1373060501921608,
#   'nuc_rep_energy': 0.720066962403048,
#   'n_electrons': 2},
#  'Total_energy': {'Mean': -1.1183663032829871, 'Sigma': 7.337674560403684e-06},
#  'Energy_variance': {'Mean': 3.5107048006466357e-06,
#   'Sigma': 3.52687902704929e-06},
#  'Time_optimization': 68719.80763296131,
#  'Network': {'machine': 'crnn', 'nU': 50, 'nL': 1, 'n_par': 8304},
#  'Training': {'optimiser': 'adam',
#   'lr': 0.005,
#   'lrs': 'C',
#   'numsamples': 100000,
#   'seed': 123,
#   'steps': 5000},
#  'Evaluation_samples': 100000,
#  'LocalSize': 2,
#  'Time_sampling': {'Mean': 0.7874837388616055,
#   'Variance': 0.003835738489822146}}
